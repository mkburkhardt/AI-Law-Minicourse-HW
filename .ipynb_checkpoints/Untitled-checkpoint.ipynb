# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/mikaelaburkhardt/anaconda3/lib/python3.6/site-packages
# Requirement already satisfied: wheel>=0.26 in /Users/mikaelaburkhardt/anaconda3/lib/python3.6/site-packages (from tensorflow)
# Requirement already satisfied: numpy>=1.12.1 in /Users/mikaelaburkhardt/anaconda3/lib/python3.6/site-packages (from tensorflow)
# Requirement already satisfied: protobuf>=3.3.0 in /Users/mikaelaburkhardt/anaconda3/lib/python3.6/site-packages (from tensorflow)
# Requirement already satisfied: six>=1.10.0 in /Users/mikaelaburkhardt/anaconda3/lib/python3.6/site-packages (from tensorflow)
# Requirement already satisfied: enum34>=1.1.6 in /Users/mikaelaburkhardt/anaconda3/lib/python3.6/site-packages (from tensorflow)
# Requirement already satisfied: tensorflow-tensorboard<0.5.0,>=0.4.0rc1 in /Users/mikaelaburkhardt/anaconda3/lib/python3.6/site-packages (from tensorflow)
# Requirement already satisfied: setuptools in /Users/mikaelaburkhardt/anaconda3/lib/python3.6/site-packages (from protobuf>=3.3.0->tensorflow)
# Requirement already satisfied: bleach==1.5.0 in /Users/mikaelaburkhardt/anaconda3/lib/python3.6/site-packages (from tensorflow-tensorboard<0.5.0,>=0.4.0rc1->tensorflow)
# Requirement already satisfied: html5lib==0.9999999 in /Users/mikaelaburkhardt/anaconda3/lib/python3.6/site-packages (from tensorflow-tensorboard<0.5.0,>=0.4.0rc1->tensorflow)
# Requirement already satisfied: werkzeug>=0.11.10 in /Users/mikaelaburkhardt/anaconda3/lib/python3.6/site-packages (from tensorflow-tensorboard<0.5.0,>=0.4.0rc1->tensorflow)
# Requirement already satisfied: markdown>=2.6.8 in /Users/mikaelaburkhardt/anaconda3/lib/python3.6/site-packages (from tensorflow-tensorboard<0.5.0,>=0.4.0rc1->tensorflow)

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf
# Out:
# /Users/mikaelaburkhardt/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
url = 'http://mattmahoney.net/dc/'

# %%
# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename

filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Found and verified text8.zip
# Data size 17005207

# %%
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)


graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  293.066101074
# Nearest to to: gordian, redeveloped, reinstate, ari, nonconfirmative, crankshafts, schaefer, petri,
# Nearest to they: immensely, felt, seaman, santana, wilkes, pq, ezek, carne,
# Nearest to often: can, viciously, oaxaca, laughter, gisela, imaginative, lawsuit, correctly,
# Nearest to no: generalities, tacitus, punjab, investiture, radiodiffusion, contingents, kutch, stow,
# Nearest to time: albinus, taliaferro, decisions, kirtland, omission, saccharomyces, nahum, majorities,
# Nearest to that: accumulator, audiovisual, weezer, scandals, asahi, primacy, innovative, interchange,
# Nearest to when: headwaters, excerpts, errands, covenants, hypostasis, illuminism, envelopes, mestizos,
# Nearest to with: dan, yaw, angiosperm, meet, attain, forrestal, arrives, mug,
# Nearest to five: headquarters, bosom, foreman, impart, heterozygous, thorn, prays, ki,
# Nearest to only: overlordship, plugs, churchmen, tax, heterozygous, logico, sawdust, confucianism,
# Nearest to see: evan, week, lossless, ortelius, breviary, immersive, case, margins,
# Nearest to all: worm, somber, censured, taoist, fines, melaka, kimmei, elbing,
# Nearest to used: swallows, guilds, simcoe, timbers, trotskyist, prostitution, fluorite, goebbels,
# Nearest to during: value, fontana, attributed, dukes, yuen, impractical, pickens, gardnerian,
# Nearest to at: overlay, varicella, highbury, centronics, nanotechnology, ninth, mohawk, mmx,
# Nearest to the: correlations, duke, moro, brno, algae, experimentation, countries, hummer,
# Average loss at step  2000 :  113.76152566
# Average loss at step  4000 :  52.5127899525
# Average loss at step  6000 :  33.4381796613
# Average loss at step  8000 :  23.3908763189
# Average loss at step  10000 :  17.976403475
# Nearest to to: in, of, and, archie, daimler, for, papyrus, nine,
# Nearest to they: it, felt, captain, exert, ads, impossibility, capabilities, entry,
# Nearest to often: can, stout, learned, laughter, pp, kubitzki, embodiment, albanian,
# Nearest to no: coke, features, released, focuses, punjab, key, a, kernel,
# Nearest to time: topics, receiving, decisions, yeast, aberdeenshire, aztlan, denying, lymphoma,
# Nearest to that: mathbf, eleven, ate, jobs, to, business, beach, others,
# Nearest to when: excerpts, zero, markov, forall, warrant, headwaters, launched, mathbf,
# Nearest to with: in, dan, meet, constitution, diomedes, ceremonial, achill, plebiscite,
# Nearest to five: nine, zero, one, agave, eight, six, headquarters, four,
# Nearest to only: nations, tissue, overlordship, tax, scotland, spacecraft, northwestern, outposts,
# Nearest to see: week, pioneer, evan, systematically, archie, rye, modal, agave,
# Nearest to all: molinari, three, require, officially, taxonomy, sense, taker, fewer,
# Nearest to used: up, current, deism, carrel, breast, collected, aquinas, basins,
# Nearest to during: value, dukes, attributed, accused, illness, case, structures, indo,
# Nearest to at: of, and, archie, in, ad, affect, dot, yeast,
# Nearest to the: a, UNK, and, his, this, its, archie, of,
# Average loss at step  12000 :  14.0105809847
# Average loss at step  14000 :  11.7670450515
# Average loss at step  16000 :  9.75945735836
# Average loss at step  18000 :  8.37776946002
# Average loss at step  20000 :  8.13717427862
# Nearest to to: and, in, for, with, of, nine, could, rotate,
# Nearest to they: it, not, he, agouti, you, impossibility, there, exert,
# Nearest to often: can, also, stout, kubitzki, laughter, learned, dasyprocta, imaginative,
# Nearest to no: released, the, punjab, features, coke, focuses, tacitus, this,
# Nearest to time: dasyprocta, topics, aztlan, receiving, decisions, albinus, yeast, agouti,
# Nearest to that: which, dasyprocta, operatorname, mathbf, skylab, formulation, eleven, and,
# Nearest to when: excerpts, warrant, headwaters, agouti, markov, akkad, rotate, mathbf,
# Nearest to with: in, for, and, by, gollancz, agouti, dasyprocta, to,
# Nearest to five: nine, zero, eight, six, four, seven, three, two,
# Nearest to only: overlordship, tissue, nations, spacecraft, shutdown, operatorname, rotate, now,
# Nearest to see: pioneer, week, evan, licenses, perseus, rye, systematically, sakhalin,
# Nearest to all: molinari, three, gollancz, operatorname, kt, fines, officially, agouti,
# Nearest to used: circ, agouti, current, up, crashes, integers, gollancz, timbers,
# Nearest to during: dukes, dye, accused, and, illness, value, attributed, operatorname,
# Nearest to at: in, and, of, archie, agouti, on, angelo, affect,
# Nearest to the: a, his, its, dasyprocta, agouti, operatorname, this, one,
# Average loss at step  22000 :  7.04926823914
# Average loss at step  24000 :  6.95003600991
# Average loss at step  26000 :  6.6300796349
# Average loss at step  28000 :  6.46134793568
# Average loss at step  30000 :  5.96154206574
# Nearest to to: for, in, abet, nine, with, can, and, could,
# Nearest to they: it, he, not, there, you, who, agouti, we,
# Nearest to often: also, can, abet, kubitzki, laughter, mica, stout, there,
# Nearest to no: this, punjab, released, a, focuses, which, features, tacitus,
# Nearest to time: dasyprocta, topics, aztlan, decisions, receiving, agouti, gnat, operatorname,
# Nearest to that: which, dasyprocta, it, this, operatorname, also, skylab, aba,
# Nearest to when: four, excerpts, warrant, headwaters, after, abet, markov, zero,
# Nearest to with: in, by, for, agouti, dasyprocta, gollancz, at, and,
# Nearest to five: eight, four, six, zero, seven, nine, three, two,
# Nearest to only: overlordship, nations, now, tissue, it, spacecraft, shutdown, operatorname,
# Nearest to see: pioneer, lossless, week, evan, ramps, licenses, agouti, rye,
# Nearest to all: operatorname, speedup, fines, gollancz, kt, dasyprocta, molinari, three,
# Nearest to used: circ, agouti, up, found, herb, crashes, aquinas, integers,
# Nearest to during: dukes, and, accused, in, dye, abet, rossi, illness,
# Nearest to at: in, abet, and, on, agouti, with, angelo, archie,
# Nearest to the: its, agouti, his, a, wideawake, their, dasyprocta, operatorname,
# Average loss at step  32000 :  5.96432937622
# Average loss at step  34000 :  5.73318542218
# Average loss at step  36000 :  5.78356128585
# Average loss at step  38000 :  5.53428438437
# Average loss at step  40000 :  5.26728080595
# Nearest to to: nine, can, zero, not, for, abet, with, would,
# Nearest to they: he, it, there, not, we, you, who, she,
# Nearest to often: also, abet, can, there, kubitzki, mica, which, laughter,
# Nearest to no: a, billiard, this, punjab, three, that, which, released,
# Nearest to time: dasyprocta, aztlan, decisions, agouti, topics, gnat, operatorname, receiving,
# Nearest to that: which, this, it, dasyprocta, but, operatorname, also, restitution,
# Nearest to when: warrant, excerpts, four, after, in, headwaters, zero, abet,
# Nearest to with: in, by, agouti, between, dasyprocta, for, at, and,
# Nearest to five: four, eight, six, three, seven, two, nine, zero,
# Nearest to only: overlordship, now, shutdown, nations, which, plugs, spacecraft, operatorname,
# Nearest to see: lossless, pioneer, evan, bandai, ramps, agouti, week, has,
# Nearest to all: operatorname, three, agouti, gollancz, dasyprocta, many, speedup, taker,
# Nearest to used: circ, agouti, nucleation, found, herb, crashes, sandwich, albury,
# Nearest to during: in, dukes, rossi, abet, and, dye, accused, illness,
# Nearest to at: in, abet, on, and, agouti, with, angelo, merwara,
# Nearest to the: its, agouti, his, their, wideawake, dasyprocta, operatorname, a,
# Average loss at step  42000 :  5.37021798921
# Average loss at step  44000 :  5.2311454258
# Average loss at step  46000 :  5.25404961634
# Average loss at step  48000 :  5.21846452498
# Average loss at step  50000 :  5.00748544848
# Nearest to to: nine, would, can, and, abet, not, aba, eight,
# Nearest to they: he, there, we, you, it, not, who, she,
# Nearest to often: also, abet, there, sometimes, now, which, still, kubitzki,
# Nearest to no: billiard, this, a, punjab, scribner, any, there, focuses,
# Nearest to time: dasyprocta, decisions, agouti, aztlan, omission, gnat, topics, operatorname,
# Nearest to that: which, this, dasyprocta, but, operatorname, it, restitution, formulation,
# Nearest to when: after, four, warrant, if, excerpts, but, in, and,
# Nearest to with: in, between, for, by, agouti, or, and, dasyprocta,
# Nearest to five: four, six, seven, eight, three, two, zero, agouti,
# Nearest to only: overlordship, kapoor, operatorname, shutdown, now, savior, plugs, pitches,
# Nearest to see: evan, lossless, pioneer, bandai, ramps, roshan, transcripts, agouti,
# Nearest to all: three, operatorname, these, many, agouti, bianchi, taker, dasyprocta,
# Nearest to used: found, circ, nucleation, agouti, herb, sandwich, aquinas, albury,
# Nearest to during: in, dukes, yakovlev, abet, rossi, at, after, accused,
# Nearest to at: in, abet, on, kapoor, agouti, angelo, and, merwara,
# Nearest to the: his, its, their, agouti, wideawake, a, this, dasyprocta,
# Average loss at step  52000 :  5.03987034202
# Average loss at step  54000 :  5.18306151414
# Average loss at step  56000 :  5.0604190253
# Average loss at step  58000 :  5.03680423701
# Average loss at step  60000 :  4.94518564618
# Nearest to to: pulau, can, nine, would, not, wct, abet, eight,
# Nearest to they: he, we, there, you, it, not, who, she,
# Nearest to often: also, sometimes, abet, now, there, commonly, still, it,
# Nearest to no: billiard, pulau, balboa, any, a, punjab, there, focuses,
# Nearest to time: dasyprocta, ursus, agouti, decisions, pulau, aztlan, omission, gnat,
# Nearest to that: which, this, pulau, but, dasyprocta, restitution, gigantopithecus, presbyterianism,
# Nearest to when: after, if, but, before, four, warrant, abet, excerpts,
# Nearest to with: in, between, agouti, by, gollancz, and, for, dasyprocta,
# Nearest to five: six, four, eight, three, seven, zero, nine, two,
# Nearest to only: kapoor, overlordship, pulau, operatorname, now, shutdown, savior, pitches,
# Nearest to see: evan, lossless, pioneer, bandai, transcripts, ramps, complementary, roshan,
# Nearest to all: these, three, many, operatorname, bianchi, kc, taker, wct,
# Nearest to used: found, circ, known, herb, nucleation, agouti, sandwich, albury,
# Nearest to during: in, dukes, after, abet, yakovlev, at, rossi, operatorname,
# Nearest to at: in, abet, on, agouti, kapoor, ursus, pulau, merwara,
# Nearest to the: its, dasyprocta, ursus, their, agouti, wideawake, operatorname, a,
# Average loss at step  62000 :  5.0277319026
# Average loss at step  64000 :  4.83891952896
# Average loss at step  66000 :  4.61701682138
# Average loss at step  68000 :  4.97121990228
# Average loss at step  70000 :  4.91131673217
# Nearest to to: pulau, can, would, dinar, will, not, could, wct,
# Nearest to they: he, we, there, you, it, not, who, she,
# Nearest to often: also, sometimes, commonly, now, there, usually, still, abet,
# Nearest to no: any, billiard, pulau, a, balboa, punjab, there, thaler,
# Nearest to time: ursus, dasyprocta, decisions, agouti, omission, pulau, aztlan, thaler,
# Nearest to that: which, this, pulau, but, restitution, presbyterianism, thaler, operatorname,
# Nearest to when: after, if, before, but, four, in, warrant, microcebus,
# Nearest to with: between, agouti, by, in, gollancz, dasyprocta, microcebus, maxwell,
# Nearest to five: six, four, three, eight, seven, zero, two, nine,
# Nearest to only: kapoor, pulau, operatorname, overlordship, microcebus, cebus, now, savior,
# Nearest to see: evan, lossless, bandai, transcripts, pioneer, ramps, complementary, agouti,
# Nearest to all: these, many, callithrix, three, operatorname, kc, taker, bianchi,
# Nearest to used: found, known, mico, circ, agouti, herb, nucleation, sandwich,
# Nearest to during: in, after, dinar, abet, yakovlev, at, dukes, following,
# Nearest to at: in, abet, on, under, kapoor, agouti, merwara, during,
# Nearest to the: its, their, this, his, agouti, ursus, thaler, a,
# Average loss at step  72000 :  4.75849553573
# Average loss at step  74000 :  4.80131425214
# Average loss at step  76000 :  4.72667874181
# Average loss at step  78000 :  4.79926512146
# Average loss at step  80000 :  4.79573743099
# Nearest to to: pulau, can, dinar, would, wct, will, ursus, nine,
# Nearest to they: he, we, there, you, it, she, who, not,
# Nearest to often: also, sometimes, commonly, usually, now, there, still, frequently,
# Nearest to no: any, billiard, there, pulau, balboa, punjab, thaler, a,
# Nearest to time: agouti, ursus, decisions, dasyprocta, omission, pulau, thaler, kirtland,
# Nearest to that: which, this, pulau, but, thaler, restitution, operatorname, dasyprocta,
# Nearest to when: if, after, before, microcebus, but, however, warrant, in,
# Nearest to with: between, in, by, agouti, dinar, dasyprocta, gollancz, maxwell,
# Nearest to five: four, six, seven, three, eight, zero, nine, two,
# Nearest to only: kapoor, pulau, microcebus, operatorname, cebus, overlordship, now, dinar,
# Nearest to see: evan, lossless, bandai, ramps, agouti, illegality, pioneer, complementary,
# Nearest to all: these, many, callithrix, three, operatorname, kc, bianchi, taker,
# Nearest to used: known, found, mico, agouti, circ, herb, sandwich, microcebus,
# Nearest to during: in, after, at, dinar, abet, yakovlev, dukes, kapoor,
# Nearest to at: in, abet, on, during, under, kapoor, and, merwara,
# Nearest to the: its, their, his, ursus, dasyprocta, a, agouti, wideawake,
# Average loss at step  82000 :  4.76166225755
# Average loss at step  84000 :  4.74421248114
# Average loss at step  86000 :  4.7586716069
# Average loss at step  88000 :  4.74298833036
# Average loss at step  90000 :  4.71976599824
# Nearest to to: dinar, addington, can, will, pulau, would, not, abet,
# Nearest to they: we, he, there, you, it, not, she, who,
# Nearest to often: sometimes, also, commonly, usually, now, still, there, generally,
# Nearest to no: any, billiard, pulau, there, balboa, punjab, thaler, a,
# Nearest to time: decisions, omission, ursus, pulau, agouti, thaler, lakeside, dasyprocta,
# Nearest to that: which, but, this, pulau, however, thaler, what, iit,
# Nearest to when: if, after, before, however, while, although, warrant, microcebus,
# Nearest to with: between, in, by, gollancz, agouti, dasyprocta, microcebus, maxwell,
# Nearest to five: four, seven, eight, six, three, zero, nine, two,
# Nearest to only: pulau, kapoor, microcebus, operatorname, cebus, dinar, overlordship, uncreated,
# Nearest to see: evan, illegality, but, lossless, ramps, bandai, agouti, transformer,
# Nearest to all: these, many, callithrix, operatorname, some, kc, bianchi, three,
# Nearest to used: known, found, agouti, mico, circ, albury, microcebus, herb,
# Nearest to during: in, after, at, abet, following, yakovlev, dinar, rossi,
# Nearest to at: in, abet, during, on, kapoor, under, agouti, merwara,
# Nearest to the: its, their, a, this, wideawake, dasyprocta, his, agouti,
# Average loss at step  92000 :  4.66805066752
# Average loss at step  94000 :  4.73070794487
# Average loss at step  96000 :  4.68770382726
# Average loss at step  98000 :  4.59807435095
# Average loss at step  100000 :  4.70174919164
# Nearest to to: can, dinar, would, pulau, will, addington, gunnery, ursus,
# Nearest to they: we, he, there, you, it, she, not, who,
# Nearest to often: sometimes, also, commonly, usually, now, generally, still, frequently,
# Nearest to no: any, billiard, pulau, there, balboa, thaler, punjab, or,
# Nearest to time: ursus, pulau, agouti, omission, thaler, decisions, dasyprocta, premise,
# Nearest to that: which, but, this, however, pulau, what, restitution, iit,
# Nearest to when: if, after, before, while, although, microcebus, in, however,
# Nearest to with: between, in, agouti, gollancz, dasyprocta, by, microcebus, maxwell,
# Nearest to five: four, three, six, seven, eight, two, nine, zero,
# Nearest to only: cuauht, pulau, kapoor, cebus, operatorname, microcebus, dinar, savior,
# Nearest to see: evan, illegality, agouti, transcripts, ramps, abet, peacocks, belarus,
# Nearest to all: these, many, some, callithrix, operatorname, kc, bianchi, those,
# Nearest to used: known, found, agouti, circ, albury, mico, microcebus, herb,
# Nearest to during: in, after, at, following, abet, dinar, yakovlev, since,
# Nearest to at: in, during, abet, under, on, merwara, kapoor, thibetanus,
# Nearest to the: its, their, dasyprocta, thaler, his, agouti, ursus, a,

# %%
# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
